# %%
from collections import defaultdict

import json
import pandas as pd

# %%
def read_yelp_dataset(file_path):
    mo_business = []
    for chunk in pd.read_json(file_path, lines=True, chunksize=10000):
        filtered_chunk = chunk[chunk['state'].isin(['mo', 'MO', 'Mo', 'mO'])]
        chunk_json = filtered_chunk.to_dict(orient="records")
        mo_business.extend(chunk_json)
    return mo_business

def write_json(file_name, ext, contents):
    try:
        with open(file_name + "."+ ext, 'w') as f:
            json.dump(contents, f, indent=4)
        print(f"Successfully written to {file_name}.{ext}")
    except Exception as e:
        print("Error: ", e)
        raise
        
def write_csv(df, csv_name):
    df.to_csv(csv_name + '.csv',index=False)

# %% [markdown]
# # Sampling for Montreal

# %%
file_path = "../data/raw/business.json" 
mo_business = read_yelp_dataset(file_path)

print(f"Successfully loaded {len(mo_business)} entries from the Business dataset.")

if mo_business:
    print("\nFirst entry in the dataset:")
    print(json.dumps(mo_business[0], indent=2))
# Out:
# Successfully loaded 10913 entries from the Business dataset.
#
# First entry in the dataset:
# {
#   "business_id": "mpf3x-BjTdTEA3yCZrAYPw",
#   "name": "The UPS Store",
#   "address": "87 Grasso Plaza Shopping Center",
#   "city": "Affton",
#   "state": "MO",
#   "postal_code": "63123",
#   "latitude": 38.551126,
#   "longitude": -90.335695,
#   "stars": 3.0,
#   "review_count": 15,
#   "is_open": 1,
#   "attributes": {
#     "BusinessAcceptsCreditCards": "True"
#   },
#   "categories": "Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services",
#   "hours": {
#     "Monday": "0:0-0:0",
#     "Tuesday": "8:0-18:30",
#     "Wednesday": "8:0-18:30",
#     "Thursday": "8:0-18:30",
#     "Friday": "8:0-18:30",
#     "Saturday": "8:0-14:0"
#   }
# }

# %%
write_json("mo_business", "json", mo_business)
# Out:
# Successfully written to mo_busi.json

# %%
mo_business_ids = set()

for row in mo_business:        
    if row['business_id']:
        mo_business_ids.add(row['business_id'])

# %%
len(mo_business_ids)
# Out:
# 10913

# %%
mo_business_ids
# Out:
# {'_Xe-dBjtCD3rmC7tbk08dQ',
#  'oAsQSIYjp56Z6woPunfLxw',
#  'UU503tMXdZR4oDZXuoKuGA',
#  'EvgRJ-09uavss9YNgnAq7A',
#  '6u51kembCosi-fLsPwUbCA',
#  'u5_9rsVeGl7imoYB6I2ahw',
#  'uasMzMp00F9azoVpqq-xOw',
#  'VxY4CW0ijTBTlDvNhGUffw',
#  'S2t65PFkp4tUM36jUH0pZA',
#  'BOjpe0u5u_cm9SWMS2KLFg',
#  'mUSuT-LtuGUjqmijPIozGg',
#  'hRL0ckObJEJOJ2irlOAXDQ',
#  'IslZvM5WfAw-iWBvaXWbNA',
#  'uTAAG6zfdoApH7-1ryCxqQ',
#  'KzCRmb7dpEk7FUTHyynanQ',
#  'HGR-bEHTZak4bCVmIR-aKQ',
#  'WY0ji9m-qAOc_6lK8h4pNw',
#  'XTc_ZwG9zt7L_dmwZahGOQ',
#  'HFLQ1jmfyfICzk95skEDDw',
#  '068DMaEKghlGsSzJPuLucA',
#  'AAUZbyoJDezAh53xQP3Tbg',
#  'f_N7S_M86uHnfgBL0EPU3Q',
#  '-NF_wBObzf5IdLzWyea7XA',
#  'TNtcjnta11CpDebuBNdoug',
#  'm6Q6z3SAkXVdidNqiKmBrQ',
#  'MDe5ehdhf6YkEw1sLmeWDw',
#  'kDJ7OtOx4VLUoN4v1m8ikA',
#  'w_PuO0-yKhdLTMkNesX1dQ',
#  'ShG57pFFwmHGpNK42NmUUg',
#  'VKyfcuU-qa8IPhKQJvoNyA',
#  '9fajAXTAT1A_pcGakz64hA',
#  '_geBSCsu-QEoO64rpEZYiA',
#  'yQrXytT_zKbex3-CmDz6vA',
#  '_0ki9SYy99XWYWT2quHPNA',
#  '4LPR7oVxoT0gWi8_c2zDgA',
#  'vqupAQF3TJCO25nC7f2E6Q',
#  'wt-nZcKEihRl6liR0P1ALw',
#  '3pDzCmDccWPifQ5qDmWQMg',
#  'nC5eK9cP0ag4kAikutFWKg',
#  'YhFd_8UtM_89Vb8GIMZgxQ',
#  'e71x7cGXFX60v0YkiqKvgg',
#  'JOfBsNewE5J0rHG5LdlZeg',
#  'wxM95Gj-GBY38DnEXed4FQ',
#  'idgx0jqW2qAa48o4tNOvLw',
#  'abVQM-Y9S4fvlQf_M4ipHw',
#  'rccTGDEgn7kwc9-KLx2Trg',
#  'lrNeXiPL5-BeIR2kOUcZuA',
#  'LyQbIKnQN-3Pogi_5ZshNg',
#  'TczbLjWfkk9whsctkoA_dA',
#  'XhozZLCTz-lfScIRZwORSQ',
#  '2xOo3zCuZ1WPSWU_dt7c1Q',
#  'ONuqYwEjR0WOSeVf0km1Jg',
#  'X6nl7nLPHdBHzjmGvrVgXg',
#  'lxaLLAq1WGXPCJLX9oVa_w',
#  'fFDgfDGOUWOaTJF9K9N4YA',
#  'LBBvTQNXwcH7IQPhpt1Pzw',
#  'JCP2vUaq_4i2jtshDtbAwA',
#  'BaT8gUzYJauTUqCi2vN-hQ',
#  'py33hI5mYwulovMZ0v8V0w',
#  'eBYhNpK0iNml40Jcgdy37w',
#  'ZJpWgTgNNfWV67lmGLjdIw',
#  'QhisfjBwBKxdSycfXyLtBQ',
#  'Yz4BD3vf8-d14j2T2FgYxA',
#  '0euXvqsW9rLABiCudz4diQ',
#  'HeWwfS6B6bZm0SSFTUttxg',
#  'q5Hjagymj3-RrzeBV0uIKA',
#  'yM8LlTInbQH4FwWC97lz6w',
#  'YnEEaQUvhd7Yh4RezvuGcg',
#  'x6YlsHOvfklMNQJ2Jd4uVQ',
#  'RyLYPpmx-befoiSEnsZ1fQ',
#  'Bd-uHVnaFvRDHcxmzJFMTQ',
#  'FQ_J6j4nIkp76gd7tjY8bA',
#  'HfoZPJwS5d_UUjbQNcnluA',
#  'mCavSZ5euJ9ujrlBXlgdJQ',
#  'Qqvt26msfxdwm2WZZI_BDg',
#  'nVyL3F7ZWus0hviop52x9w',
#  '-BHSeNtP6CoErp30iGDxPg',
#  'Mlh_VH3ZVbxMn9NXYcRRAw',
#  'fVvlgMz91aQuFqa5d2RirA',
#  '6AjtvfJDJUAqrFA7lVWvMQ',
#  'YpH3mZPgyu2VA0tFy48C_Q',
#  'fmltN_xSMyqlKGM7tlV4qg',
#  'IOm2_nrAx7nHvFufszj9Wg',
#  'sUB7GCmKU23BHZEj5GRvyQ',
#  'cpIhehixXt7cajwNYpRNbA',
#  'pSLOLTtA_MDwwGCuXssXiA',
#  '3Y5rFbzRT1kUky7KSlMhPQ',
#  'nTSBlrhqzdoKZpRZf426tA',
#  '7MkJ93ZgYT_UltF_JSatVw',
#  'qJdr_VOhIHP-CyxwYbPOSQ',
#  '18iMG9wb7i2ydG_Tra4GCA',
#  'Sgp_0NFKVLmqGD7_Sh8jag',
#  '4EV0MvY9JHErxMugLYt1Vg',
#  'GMh_lOx239eIHSPqB18NLA',
#  '9ejjlo5CbyB6hs1CYP8lVg',
#  'BmKCJsV_payJ5ANqC7i85g',
#  'Aujzip703SHH448aFv9FEA',
#  'L7P_EAfX0chnAOjchcdJDA',
#  'cO-EBH0LC5VZEc007C8Gng',
#  '3N4njaL8JzaG52ETpn3XuA',
#  '54X8EMNaeeMjleWUZENl6w',
#  'utJRw1T1_zjBuCIFFIbe-w',
#  'c3EqDlTfKlUxu_mFA46JTA',
#  '6ECHG59P5Bau0tGMzPQBSw',
#  'frREs_vJQ6YOoma4ZdgYNQ',
#  'Lpuvf-1pHW1Roh6bPm1fPw',
#  'CiIQm23jT_2qx3LJFwjoDQ',
#  'vWjME92WddneF98IqzaNfQ',
#  'usaeB-ZGjBhOJ9QaoON7ew',
#  'laV1qL3qhGFOfkPbHo3SVQ',
#  'Cx68iUCPklDLV7BujV6iNA',
#  '5P2a28kTVFsTkQMi2fy-aw',
#  '15W0FrxH5jvJ2hqkJPKZxg',
#  'UtEETwEzjFWhm1CMvOY73w',
#  'MaaDRJZKSUTAJeF6OTQRnA',
#  'qEVC6Q_QaALvduNPURqfTQ',
#  'RuVeJ30UzNEryARU0HbQlg',
#  'rQGqV0vSF_vhXA1LINBdBQ',
#  'sWZnoOJwHTQD7RgdrmFA6Q',
#  'Sks1IMYoJd8pQj9uSfNYXA',
#  '9b1MIHEAGz86HInI5IiRJQ',
#  'yQDdYXRhioaw8HxS42lwzw',
#  'Jc4doWAvoel26vQ7hhzcrg',
#  'pBlPDWjnZWh7HCyccpNeTA',
#  'Chd7yTB57JKVRcp-WGWsBw',
#  'hQMiB0cZVOjyThqgKlQrSA',
#  'wERePw1_Fg0RM-NYDDFDJQ',
#  'qyBCss1n9ttwSzLb7JQSAA',
#  'AlWSX2emcQScapdb5cu6Fg',
#  '0gDuVXKohD3hfrryK9tEOQ',
#  'kWRyN0Mpt22WcRBL98Qdyg',
#  '0F6J5VQ-nKC0NeSJuZgvPw',
#  'uSSozhfHwXJnOf47mP_UuA',
#  'Cqi8_Q4wj2ZRHCy6ArO8Gw',
#  'WuEj_th1_CylYddnvXknog',
#  'ul03kWvQ22EadE7eq2hO_g',
#  'Z_7P0pQYeMrGlC1vnOtEAg',
#  'k_Q7IT0Cr6-2TbByjus5sQ',
#  'MwhX1qkaz-9Jw1uiYSBV5g',
#  'mGvrybwAiigeSAn-sTNlCQ',
#  'diMeARJa_5CDNe5ImBlCcA',
#  'vRj1rgF4ZpwGt97MbcRzqg',
#  'bW3Z2Qp2rIIfZwBVP3j4Ng',
#  'B1L6-hN63I1S_cAijI5Otg',
#  'P61ecBVVPgBm-zH_SYq8FA',
#  'X-XEau6W1kS9Zpo3nJmS4w',
#  'CrF8GhrF8KJikwugSci5lA',
#  'UK_VZor0koO8wYg7NSMlzA',
#  'KnnADtzYoNL24DQ_M2DLcA',
#  'DgLwvHu6wNt2SrFvE5xxHQ',
#  'LlyUylPsVTOJ9P0Sk4_kag',
#  'EGWB7_SP4Ja7_z6A6Md8gA',
#  'Hn5wSB6hKqKs-_fzAIocJA',
#  '6mxuP4X8OQ1_mEnxkIVXiA',
#  'lUKlB43bMcyn64hTFttTAg',
#  'soKWUJFw4E5g5pfpws9Gmw',
#  '6wQvpmT5vO1oq5mw5lBrTQ',
#  'WO5tzsvDOK0o0rbxcQbgyQ',
#  'w4mYmiTMs5BiymKKlgGdlw',
#  'rC9E4SRLvo4nAfYx5GqMeg',
#  'M02RJ4qUSiNpcYMBEVu1ZA',
#  'uSw3X8i2qisTUmuoHbXsIA',
#  'HuRJBBn6UEm8OhMSGXFkBQ',
#  '6kx5nIZh9bQ_02_GOcE7bg',
#  'toNBqXtpFxM6iRqaJj4-Kg',
#  'NbeiCBZonsofk4yLd4h9Hw',
#  'H4hZ2aFEffDXz8Gi0cBchA',
#  'pf4-YHmxzkQmntN99fF95w',
#  'N2o0ildiQXq3kG7I4voeNw',
#  'qTC1T3snVumwGLoQUUapxg',
#  'WHLM6UhwSV0tN3CrmSgsUA',
#  'uzfRXzHPFOlXqE863Hjzqg',
#  'wgEHdS2er6r-6wBv_tnnYQ',
#  '2jQri_FEXz0GIsYlAVqyJA',
#  'VK_QBt3RHYSPEyIEBisYaQ',
#  '8iRDDLFlujkRt7ZbwXSuJA',
#  'jX2rIY5pUtcoH6urQ4IYVg',
#  'S0UJxUiqCsT6VHbKGPn-UQ',
#  's6FG27VMDcuBvq36ls213A',
#  'yBURti4UdFuTsBZe5sCLOA',
#  'ZURsetoygYdSgmDwHnyiAg',
#  'PR3McPX213ccnC_Sr4-sug',
#  'QomMGi8F1UqvCzSTapG01w',
#  'DfJva_7PZV-XIjWVMoAfaw',
#  'Z9iIULY9uxOjCcIesEEIAA',
#  'QVXfW1c8eOm9SJVb3xdo7w',
#  '1yPJRGvPNU4voA6NBTVGOg',
#  'cEgsHkAnpYQbA60pIIZYKQ',
#  'gJwkEWX0b0vxIKQX0_vbrw',
#  '_ystWQYoKMOge_zQj1cpEw',
#  'Hh-Fx4XKNghlHBC8CVD0OQ',
#  'Gv1viz1bePCzeWDNc4tosA',
#  'MhJWhx0f2YntEPVhwza1WQ',
#  'TfYFyl8WFLPKGTcRz8AMpw',
#  'e6f8CiTLhFbcG3akdyNu5w',
#  'AX4bsa-cmMnjOCx0f75cTg',
#  'dvYDlWU63ZxehlETpO5qwA',
#  '8t3a6XoVbQ0nAOwCzpEsaw',
#  'wT7Vwqs0gySYHVjApTBS5A',
#  '2Kck2jkXVsMde_nw4noxjA',
#  '2UFF9wckpTxz777rj8YuVA',
#  'C4q1Ishe_ER15oh55nXBKw',
#  'cXEx8dhmoFZcsJjXS2lLuQ',
#  'ytCOKY0u-YIFA8O_iUX7OQ',
#  'tKIY9qXUUHIqOXXyT5EB6w',
#  'UBxJ4BOuEoRJKEJ-DStIvA',
#  '1HUJGIOAFDHnBOZ06lXkGw',
#  'qHTPHDJBs58HJCt6K6epNQ',
#  'oxiDET8urGs-6ufZ0yP6DQ',
#  '7K2sR2vJ3HRGMQZDcDHwag',
#  'q5a8uUY821cYI7cy2UWv_w',
#  'FkBdvg6okJkKel2YWnlWqw',
#  'K38t-YmXMDPShYCNzpGrKA',
#  'H2LgP7v1embduUUxsSkzIg',
#  'cbxSRh4PGbq6epMaSd2KMA',
#  'GGNAv3JYltchkmdsw8Aw8A',
#  'Gu4ZaiixlQ9uP7a6HU2pSA',
#  'rEVriaq8Kem4Jwj6uXGOTg',
#  'Gj-KAhvGJ8PNy1xo-vOMDg',
#  'JKQ9Je-TPOtpIjNYSqrkRw',
#  'Blu-xIRaFO7Ktyj3ZHZpdg',
#  't0JqTIm2hlLygzuoy_6aNw',
#  'w75_ifwe52UAhhOYXDAtGQ',
#  'FH0bFrryxxwcStKLC4kb_w',
#  'QaOTMn7BVBx3xXrjRlVnCw',
#  'cZ9VLvtd5t4cMe9yT8nQoA',
#  'qBpwohFkIaYzHMfwrOLMzQ',
#  'WFdIA0fpqQwO_219H8zfQw',
#  'l7_TZBVibyGouWfx4oUU1A',
#  'I0aLpV_Tl6Sixr1xzJRPUw',
#  'RZprk5c9cKgQdOMolW4C-g',
#  '_z6knHiE5xtp5f8jnOmy6Q',
#  'FlWCsBiNoI4XTwZD8f_q0Q',
#  'nr5WdWYxo-jQOezdaEpbpw',
#  'xQARL5AiAK1atc_GG06S3g',
#  'lHbWjwIFb1cPlnr73IzcMw',
#  'C_FFlssuGnK0lr5QhGVTDA',
#  'M2PmebgYDEN-Xn8VYN3-vg',
#  '62o8oBwkQcbO3w6uoYP3FA',
#  '0DJ-BXLvxKFhoT_Wc_mrxQ',
#  '-6jVwUuXC1-dyr2YRCEU6Q',
#  'N2vUq6LOvvRzKB5zj4v0Rw',
#  'Wuk5lIvr0kLovJYzbTyrSg',
#  'BtcY6Oa5ogAmQmABKTPyiw',
#  'YAODh3sX3kS-wxGGLdEMpg',
#  'L0_dkNVGLY9lm02fdpA_gw',
#  '-dzKS5d4Xh2UrN4ErpP0EA',
#  'rifxI1dZRqMWrPWbKSdvyw',
#  'QD_4xvbuSc-1U8wL6K4BEA',
#  'o7LSwqYMkhKzoyctobM7DQ',
#  'v4S374WpOOhojqpto-AaAA',
#  'dYMb9V0rUmspH-59KnobrA',
#  'z96j_GQevSXIbYMXPAzczA',
#  '5VL5v7Bf7adKnnFYFYxmKg',
#  '1izvDSXzdjNpCBCo6ru2KQ',
#  'HTSsRjVLvqa07O-N98EM-w',
#  '5HgQyP9MfSXW-5HeCYL-VQ',
#  'ezi4MDv0X1XfmkQ_D5_lGQ',
#  'N-lApE_FMwhqN17zSNnyMA',
#  'Tm_CKv5VauVFUZIkndo_rQ',
#  '0JpbgItuNiP4KJ4PQ3YvRQ',
#  'bjj7HIgdC04IhctuMMIF1A',
#  'FjhHnVUJUYzNRq5F1ORziQ',
#  'yGKeP2m3RefZY-kFqjTNGQ',
#  'ZfZhTZ5CHU5LQDeEUGsE_Q',
#  'SEWYaGpr7XxcLSQFYSV3iQ',
#  'O-D2eTl-opIWIK4OdzuVDg',
#  'zhClUvnf7-aPxtsnf_OK-A',
#  'AyNT2MfX_PhUGF4QA5U5OA',
#  '06ZYW6QE-5dHmZGyNrTiAQ',
#  'ZALxLqcIfrW047KDHwhiDQ',
#  'yj5v5Q6JiVMHGwgdvNt3WQ',
#  'Lx9egXm9z-A78UNLNHId3g',
#  'AAofsgPw626w09OX2aqj_Q',
#  'PXbA_eou5-TdVq_yeIPQBw',
#  'ODkI9Un0otrGfUtV95ShTQ',
#  '91_FOBA2-fJJnWRgDjRqPg',
#  'OO7XTNqC1EYEAfTK9zzdTQ',
#  'lzxU-a02IdI0faEebdZYDw',
#  'AShaZXEMp3BkkREG-FiGBg',
#  '64DfFB2Dkf1HWT6l2mCvcw',
#  'BzJnfIEOm8nfZbri8HCv5g',
#  '6BifsjAz-s7QGe1GdbGXyA',
#  '2F5oD4Pa1jNaRQzFEvE1Pw',
#  'FJjJM6eM94yY5kExmBpbuQ',
#  'shE5OtUCphF3Qtz1fPBV5g',
#  '5MjB9464NZhyJGGwNeZuvA',
#  'MHq_JVpn5a6HrIXrfqLCiA',
#  'ucPOr0I6zg8YBrV_t_Anwg',
#  'NvMYRJ_wPJmt4FFsEF7O0A',
#  'zpSEaWMEysLB7IHS5W4fjQ',
#  'e32XMwd4bICY3XAhNdUGzQ',
#  'aPykWghObw9bVQKyiQPJwA',
#  '3Ym00dQ_oqZ0zunGMLhX3Q',
#  '1liiTsfPbK_POsNp52A7NQ',
#  '_H30_Y_YcQQ7kbix9a1KfQ',
#  'CiAUeiUqmvea95hHp-wMbg',
#  'Yu3z-6kGRTYg82F7wRmvPA',
#  'QWUhcLhBnWnNVNOHbadwlQ',
#  'dUAtskhiZO-MQnCBJRBxxg',
#  'fi264Jd5ThtqP-QIgzzong',
#  '3F_yz58Xy2vQedRI8WiBCA',
#  '2PoOHicWPwVtetWSStlh5A',
#  'RARZWU2ZhWNypFEKwKIkBw',
#  'tKx_ILTK-qcVxfhxEETYgQ',
#  'tqvjjDrbPq9RdRisFvLQwg',
#  'ypDJ2xwSCUeDYSqkGE3XSQ',
#  'mkR4wRGnEh66H_EAFq44TA',
#  'iOneMCZY-T3w4aisqi4R2Q',
#  'HVFvOKM8fIlxzIH970tZsA',
#  'GpXjlH2YmNaxVFxQPtiUfw',
#  'MaMHdH83puh8xJVAMHCkRg',
#  'Cx3gpL850ZeHPR6XFGi9jQ',
#  'zKOSvTY4AwsTImK4nxphdQ',
#  '1kn_zpKClcc2sWiooIwsAA',
#  'A5ZOxjJUE3wyRFO_Xy92xw',
#  't15pblhsTMQqp7Rh7KgHVA',
#  'BkElkLrrFWFrPnNlTWt49w',
#  '1YPXzsbi7G-EX5FiAzg4MA',
#  'qAVGzBznuv-vvX9MHJvRwQ',
#  '8hhlvtPzTY4pxvjw6iF_tA',
#  'HCPb3yfk91x_RPRs65UcTA',
#  'y2N7HOJzthnlAL5UNeY2DQ',
#  'T-wSzKIQaWySTLJfPmmdiA',
#  'EEs_jK26kMA87hc-5_Ni8Q',
#  'Ww45_LjdEnbhzx8jYAw5ig',
#  '91lYQWaMRHgnUlwv2bkkEQ',
#  '_VVA_fbTM8eKQq4A57Y_dA',
#  '8lao3fRZqAKJQNKqR3xbpw',
#  'g88mb6am4W2u_XNDN00y1A',
#  'LVZXqYWc6lhimxmsJHur7A',
#  'HdBfXvOD-JpLfq7IV7coDQ',
#  'C4eNdMsj9ZvHgJ1OeBf-LQ',
#  'oHWg8fQBLm9SqRcBMTMfkg',
#  'SG5OLEO9z0bQ-Fc5o5TghQ',
#  'FTsU1vykdDcqfP1uhqG9YQ',
#  'xWLjbxLrXAAbZZoVzB2aeg',
#  'wvM7vXUZnPCvYYzdYlbV1Q',
#  'RYCfxYf742ks-BbpJGeJVA',
#  'GZDBpDX78pPd7MYzQ_aQ8g',
#  'rElxptPIJZicDM39e1ORTg',
#  'sAat4Yz-DxeLFkdlXo6Rpg',
#  'NavSWYi6cIGii6kpZLpgog',
#  'svjY1yrQwzPht7iwXaTFTg',
#  'GoWtRH0p8mwIDrDhi3v85A',
#  'iBMTFUGYsUWhUUckaTyziw',
#  'EzcClnN3NClTjlgAxsFupQ',
#  'me5hhVG0wjknIK6C4hGwNg',
#  '-zb9n12C4XxsY8ZVA8XM4w',
#  'FaCZnKQellfpGPhCRJh6Uw',
#  'ZC1uwQ8zzWJG_3EGcPvVeA',
#  'hBs8DMp5pqgc8ROrNNOwlA',
#  'n_X0na4AQvFx2oSkPiGaxQ',
#  'snJxU044eHo5ZQgU_vtaAg',
#  '8ZJelsRQaVO8x0ZZpAVpuA',
#  '0TXSa7KgNlpBXgyXDQvekg',
#  '-q4YqKsWJY6NtkQdnNeL1Q',
#  'LVrpR1CT_TWQh9rguvGhwA',
#  '5cfMUhe1MwlH2EUwIuUZcg',
#  '8ZYknxtylKIULaLKiRowdQ',
#  'Q1dmj-58GVhfltAVEPpVIQ',
#  'KdlvfzVbxX7wcEKo_k4plw',
#  'ZT-ztSdou7vxKkkcMyAG2A',
#  'G7AEvOxbIUV2Em7FMmwXGQ',
#  'qDk-LG5JeLElB5wK1_oW4w',
#  'AZ2Y73dJwn6RK3H1FlO7gg',
#  'GrJzszvUutLwI5CsEX2D2Q',
#  'FBo9ZUfGJStLAHxn131gNg',
#  'RxgUFGyeB7b2GxADvwyTGA',
#  'H9ZuO-imuJjg9DgVvRkb8A',
#  'dG1pPWaVoIHWMIChKjfolg',
#  'M0c99tzIJPIbrY_RAO7KSQ',
#  'OqCeKuYIYVZeI5umQM4Y-g',
#  'aOL5pNBW-XBaw41hSIQHzw',
#  'RaKUt4jVFMB8dACsA0QhjQ',
#  'Bv1eO5cFOGO2SEUzBXNb-w',
#  'XcH0865G4TLVecSbizwRng',
#  'azI0mUNLcQbc9Mz6Db_nEA',
#  'A20ov0AIwYG6PYooI76iwg',
#  '3f6HTECaJK4vQr4VSU1xsQ',
#  '3yk9H9PPUTbPe6sXJqubaA',
#  '1AySwnhzU2v0CWVgZgIpZA',
#  'cXsrd3SqPh778u2yaiAslA',
#  'kjX7I5bywXku18py-chn9Q',
#  'Lf58SBIc523Yr_FFk8c8SQ',
#  'oSr0I7gJwADuiLKKvqLC_w',
#  'zKuLEDfLf8ruMA4Coqq0LQ',
#  'WKjAuVKf-xK3tsXk-vt7vg',
#  '14Zqh4PPwymE6VBtdLdupQ',
#  'JKztIQpa6XpTDxeMHXaBTg',
#  '4tnt0ePf2buwPimkci1ZDA',
#  'emnwJoK6hjg1NpUudnkNjQ',
#  'h2hRql5yjb4HUNQ7v4DECQ',
#  'gRRXrG7h_Zv-wXGDvfj0Tw',
#  '5ufcSii8MbAI3Yn5BQq2tA',
#  'noj7mZPve3FbamB-TeYtVw',
#  'K29-nM9dOgiYUC1ACqeyUg',
#  'gt-xjj3QJP_hFPhX4E9nOQ',
#  '9RSsUO5Ou1SAsY0l5Qu-Fg',
#  'IxJ7f8_XxumSdHQpMIHr0Q',
#  '3rmKHpVUfV9ai6yZg7ZZYw',
#  'LrF9VGLavuncYc0K_xbcdA',
#  'gaTjHHL3C-8oY5ytupIkXg',
#  '5HkAwdJbFxvvAKp6AhMkpA',
#  'YkQNkDZY0hd8tP3Em5Z9Ww',
#  'FG_iqTp5x-JXhnIFsZZBUw',
#  'TIZVONbbiaO0Gl4jnKQCqw',
#  'yxgcU1AMsQETOajo-DG3AA',
#  'X7in2ykrp6D8uoRaS4MNxQ',
#  'bMmBg_TWA3gL-GJqSSZwKw',
#  'kYeHyR-2OdTFYdWq59T3Ng',
#  'O93AIQy9P4YTYDlRl5rRUw',
#  'AamfzJ46T57ck-Qr5B7fAA',
#  'x2XtRg1HJwoyBDQE26nQsQ',
#  'wlFSzTiDNUmEMv5s58jjjg',
#  'hJhoNrYjYKegeQRQ6JXNHg',
#  '26uQ1fCPjDrqaIa0dT3Ung',
#  'mw0Hr-PsJhpJzr8NbWuSfA',
#  'K1hcCRAlbdeKFLa8B0zHIA',
#  'QDVftdeX2zWaSbk2-dbCyA',
#  'nrt_kZKsirgTFB3JY_bKpQ',
#  'PX3xJq76hHYTLZHf_htdxQ',
#  '5mlZKyyKDDHTeS9FOUL2QA',
#  'ZnY77IphK8pTi_jPvSAA9A',
#  'TDmcgUZFHC5EECpSxqfgkQ',
#  'GSikVz_j29G-DvupRPxD6A',
#  'AYSyxtJYGzShxW3-Ox1CQg',
#  'NjnnEno75pjdfx7qHkTlhg',
#  'sIsloYb2Jnq2JlUkend0Ag',
#  'cAqCeWKCGeZPlcBj0I8f8Q',
#  'FrfTcqkisvqdX_rHwlOBQA',
#  'QFzfm7Xe8i_7M6oS08c9YQ',
#  'DmWO5ebBujbRpe-vxAzDhg',
#  'snOcakQo2Qzq1xJelFjaLg',
#  '58iZ2kVIZdYdcMNrvrgtjQ',
#  'aDYzY2dYy3nlzLXmn5W3NQ',
#  '90pJu2O7fIEm_N31Fyue7A',
#  'FFu6XZHzvLsrlZlk7gHsWg',
#  'D6qYFxF1b3nrQxSooQ7DKQ',
#  'Dl1alpHSJE4_iB0MGKRLXw',
#  'alyEmOpxzjiBPhRY8bUN5g',
#  'bYD0Ks1wbI-X9J27GhV8Kg',
#  'xHdsOp-oXPGkSDi9xWSF0A',
#  'gG3MirYmbWvswSILGbkcVw',
#  'NFtgdII1WbMyl6ems1yNAg',
#  'vD2jzpPv4iyOLKzITscGvA',
#  'tnwi7be_Thc-C1m6QIwv9w',
#  '87Ib1kJWiaULafXY1lFcIg',
#  '1MDbfMLDJmapYF8xALXIxQ',
#  'psM3FUBekkIRj7HvrbBp1A',
#  'EgrnyJq6N1HSMWv4qbJ46w',
#  '1fhQkX_c0B1rV_S9fZR_Og',
#  'A1aBsqHQp-QS2LR0giS4FQ',
#  'nLSxxer8E-c2Zs_asUvbzg',
#  'YVy2DgGfNmG5hWYbA7k8jg',
#  'dN3b5sbftUBg9Tn85QHa7g',
#  'CEsFAZp1pBf3sicoZa9AYw',
#  'JgI81IdqLHKl_jhR0gw1MA',
#  '36dRPdXOM2QNNjswNmg5zg',
#  'YGTg9qMBkxw7JNnEesV0Mg',
#  'W-56oYjx245ztaFcsBPqlA',
#  'mN8jXaxRIq4iZpA-CX4Q-g',
#  'sC13uP4N2wXtmnCgExD--Q',
#  'VhIQ5lsSCJwH3Oil5rECDg',
#  'dqfincvqed8gse3NgA69ZQ',
#  '185JxNHBAz79Hg4QOzvz0w',
#  'pdk0HYEvgjpP8i63mL9M6A',
#  '1KSAK11mi_Ij9rlIH_MN6A',
#  'GuGlXaVDljVJ9FM-euhJmg',
#  'igDprQyEdLQq3h3R2aa7vw',
#  'cN8F-BmoHoS9eCqIHMtlHA',
#  'x5IZks-YNwaZNavSkgV3JQ',
#  'J7f2z_xYbBJmRN69VDkOxQ',
#  'ihlTw_LYDRH13hvO7CrpFw',
#  '7DpxI5_OvGpY1bl4I_YYcw',
#  '64rDIWaeayyumSWprWAdfA',
#  'aI0BLCA2XFefXRqgT8Iz5A',
#  'R5cfCv79Q0xytDN_JHPEtg',
#  'i7bxk12_wtHKP2SrjO3csg',
#  'Ax97IH5eJZFsBxZC9BgHEQ',
#  '5sTEdQOpJBSWT_tXqneS2A',
#  'zRMjppLqzVIvhPIy71FU6w',
#  'Li1er8KjvYKZ1t50vn5XFw',
#  'CueuRgYurL6IBGybuvQN6w',
#  '3WIP9e7hAC9EBq1Kxkozjw',
#  'YoBEPDuyBlWFjDhyHC_UnA',
#  'qmRzAqqPtvL3DDOztnIv_g',
#  '_SbEMlRqC6vm9Xf_-iomHg',
#  '2Ewv_cUDkJFl9GvDClFEmw',
#  'JP1tO2oLKd2GUtywy5whSw',
#  '4YCTMWXcqAl91ZCVBGOrVA',
#  'Qp77EOPIFpSsgv5DwC6icg',
#  'TPK_22Qx0mLzrlPlDNrAwg',
#  'VloIgAs51zkskgHMQc5Alg',
#  'C0wTjg67T6jPvw7M1wsx-g',
#  'wA0yBF4nfApJ5MsExeEmJw',
#  'TCKYfqnLo0is-_5BmLefaA',
#  'vUIZAqtgNqRPj7QCtTl3sQ',
#  'KBWHXEI314W3Udm36PHQ-w',
#  '-OZlNh1DNnApy6z8cYFLRg',
#  'bQWsA4EtGug30CXijNVYpQ',
#  'LRPcIFISwmH1IUN1PGEOmA',
#  'XApixk-TNy3fVomQ3ty_jw',
#  'TOranOczvcoHSrpTTbC3tw',
#  'yQF5iSsj5ayznu-bDCoGmQ',
#  'fma5PhETY9wxzn1nO4d0Gg',
#  '77JJM1gXrF0LL35-kVgg0Q',
#  '1CSIbwwVasAcQgmMbEwl6Q',
#  '2nepvaiiLMJhZj_xupfq9Q',
#  'iSV9nnM6eFyZzCv2Jsy6IQ',
#  'RJ_a0Y8Skjepd626FwpDng',
#  '4gxgICB6YhMB8M1xgJ8VnA',
#  'yyG4ws2y_GzyDThc_t20Eg',
#  '66_WG_4S4tqInf2Oo4MBaw',
#  'ey10d_UH8uS7bDIJLDB3YA',
#  'R1lq1J42UkLz4sEOOG6CVw',
#  'wskZf-c4YAmtLA1i2WBKww',
#  'nmO2DtYPScPrr0eAkDcVrQ',
#  'npJVCxg5mzGkM14Hc9yXBQ',
#  'DkePId_VZgMx7skQ7aqMGw',
#  'KkWQcqDPsZb6K5R5T-XJCg',
#  'Fx_yFwHlHboVTTj-4NJQyg',
#  'NMY2ZYOYLfQyp4k_YIz5sQ',
#  '1z-WWpERPYI6Q4rr8M6UgA',
#  'GhGoWiF1dP3tnP_WSPdi2g',
#  'ZP2tEg1AEcsLkQnbzR3FZQ',
#  'YEidoUyZ2kyba1AXOUuPnw',
#  'vuPu7HGfESD14yLkfHY0Gg',
#  'RZWy7iy0X-AkOiUIXiKhYw',
#  'tA335xkefgX69QhY3-mHhg',
#  'lJdfvjtx-i6uszixXxeuWw',
#  'gFUShyfbjKrBozOD5ePOuw',
#  'mXb3iNTjFF4EmxKL-W1awA',
#  '_Z28lFtKhOJRt0UXQyrbWw',
#  'cX0iIvy5ZYD-JEc_aKSM-w',
#  'z4TbMYlMITbpsR129pZNrA',
#  '2DFIjl7GtOALCFS4ar5SiA',
#  'WoWHsRSjqX7CTh92EFdwLw',
#  'pU8RA2RXV1Wj8XY0EqOpjg',
#  'AC59vRxljK2jHy_CTMl9dA',
#  '71UMJqpbiMUuHe8iA7SkVw',
#  'EXIXULfAW96tBzTzilM_OA',
#  'oRY9axuwOQSN4HbTu7obtg',
#  'ARgidflSXPHj7uhK-Y7hwA',
#  '13woW0n6ZZ0fq5u7p1CsPQ',
#  '7kZjWXFExQgqy_TheGOTOw',
#  'NIEVMHDegSZ6E_2DhqXD6A',
#  'mjXIEy_xVd36aJqj9L2gBw',
#  'xhcJ1A6qGZkEzF9vjwC5iw',
#  'QDhJUxktOFG5H9L8cvhDmw',
#  'GjojmcEcKHaVOk3Aw-wUkA',
#  'jY7KNYKfAJwa_XhYVTOx6A',
#  'cH8FSlctkiZ-f03BsQXlCQ',
#  'YSkSeCmWh5grq4dOrUM7BQ',
#  'CRz03s-0DL_r1Y35XlXkPQ',
#  'q-QpToRHSnxmCrXgZHP1Vg',
#  'gpBzLsd6OEjltZRWauoOVQ',
#  'Z4IkYjHukxG7kwdfeXTIsw',
#  'hIATKOp6jZbgsIFZG4DrJg',
#  'CcqPX9PV6vHS7E9rYlgKoA',
#  '94comc1YjKMNU-WSH-Fznw',
#  '9U76lq1i3qzNZfRPSMceZg',
#  'd4pz3Y_VoougYFxVcwvu7g',
#  'ZwJEcZAAX9do0_r4PO_j-Q',
#  'iiBCWBFwb_bzlH9usC5XPQ',
#  'vErAkgkOy936Ru-LFiEnSQ',
#  'YobaJD8A-K80qKzYsKhlEg',
#  '3GbEPVrW7IGXy-wbbl4VSw',
#  'yEh8qZoW34uoA9xKiXnCow',
#  'iCli98lWdEh_5xyWzBvE5g',
#  'tSeB6rwi780-hrgTW4g9eA',
#  'etaIhl-sduOKc6J_qHmmtA',
#  'rXu1MmfgZ8c8qcMRM9scrg',
#  'O42DL1ha9xPQIgSGNsNabQ',
#  'U11YzwqthKNbpZeyufveEg',
#  'd8dMOq7i_jo96C-ASYPnZw',
#  'Jmlqb5UYfygtUXugrpywjg',
#  'cP8E0zssOTNAtZQ20CIboQ',
#  'R1dX0mdcyK1mnNGnyEcLSw',
#  'Qs0d7uTDdklcRgkiqtfqbA',
#  'y5YGh-bzmX-kUCTE2-sWiQ',
#  't0ERxqCJx7c043WMH0_vaA',
#  'dKEf7fcc8qElzcCaAClezw',
#  'q7efJ8tXdlMm7aX-Dn91rw',
#  'b06aNwm0KgWbCBDZf3Kvxg',
#  'giEJm-5fmEyf_s3_9tgTKg',
#  'sZ59rIvpI6MZinRBw06tMw',
#  'Z5mUXtXToAdcybY3Bm3u9w',
#  'QB1V44T_lH87I24NNpPOUA',
#  'IoRjXkiGfMQskwb9XnEYtw',
#  'AExZ7MJ1lFTSQHqv8yVG3Q',
#  'ZDkfI5rpM4sywZG0G3bhcg',
#  '5rVEb8crter1lMDTyyj8ww',
#  'ZFSWym-FE81X6uLuTjoAYg',
#  'foGCZBmTVLvG_BOl8RTIZg',
#  'Tgzx2FrYQMOH7a7fJq4W2Q',
#  'MxRCy8mCzNJVzZ5EgOSiXw',
#  'aFzz6Y6xJrVz5D5EDgpgvg',
#  'Em4WD306nkJPZnKa6Iciqg',
#  'QwnJdt0I3LryvlfVP5TwGA',
#  'JNMhx1nG6bSrlPpLdYuzlg',
#  '8yIVkJ5q7abVpCMhg7PL-Q',
#  'Y4z8QSpEDdAC_zOZsetvEg',
#  'G3w7XlKj1kf_5ddg4Faxpw',
#  'lHiRVMjnxlebTMtanVJZ_g',
#  'zv1mH2hoGOuu6ALzQ-14Xg',
#  'sA045I9agFOFUAofzm_buw',
#  'EXkktsXZUspphlOWqlWa8A',
#  'RzwkGWtvkFb0ro3cpSgm4w',
#  '1P1xD7dYMrd9VseziFi0bQ',
#  '-esTQ3DICAj44W_akW32Sw',
#  'udp0E0RMpqq9jU9jiDKZdw',
#  'HJrzhwxiicQodhAj9EzrBQ',
#  'Lg56ObdQsnKQazFVC0gxbw',
#  'W8BvdOf-fa_vV4C5fQEeWA',
#  'aybQr9pMGG4U2XpI6dCS2w',
#  'YTsoRrX34rNrSSyc-e9vyw',
#  'ixyQUGEg7QhaW1UgGAmrfw',
#  'UN6gUThzB6Zvny2zKfKyUA',
#  'Uq3TeZntzD4N0M8Xe9ytAw',
#  'wdHEsSUZGjgfaFKMABXPUA',
#  'sKsHHeuJEfelQDAL5liqGg',
#  'Hu76Aq4rrCu8jwnoUNQ6Kw',
#  'Z9ra0PkKNznX3SjKvHtoDg',
#  'A5Fe8z2nA_FoQ6grZq2RZQ',
#  'C8JxRJxXnlTe2j3wFcClfw',
#  'caMiK8Cu3BqixHSGzhJbEg',
#  'oWziM1_JwD8XW94rVz7BLg',
#  'IHNKQZMZY8dmwsXKIvtz0g',
#  'LYWCOsPZpe8C1VL_0Eqw8w',
#  '7jAhxpERKakOQsxepweZsA',
#  'Xk7mnDRL2SOeQjbS8DANZA',
#  'ft1NR79l73ujfDhVp_1GMw',
#  '6KsJ2zN2jdgEiQidiRczxQ',
#  'tMGpWQB6vYRSLvP4wLrXyw',
#  '3BNO6PRQVJFGlHLar3na_w',
#  'wz_7_3PsEUpApmZVdAhtYA',
#  'PNNfQacKROs530x6PnZG6Q',
#  'lEPJ84nrSXOOASe2vRLSkg',
#  'vy-5wBnhs8WGQ819j75N0w',
#  '1mFEwKnBr0rgQwX-n3pRXg',
#  'zwcWzqineLPY4qDhCJ2Jtw',
#  'cN-E9LtQPXrE00iaQQ7UCQ',
#  'L9kzRVDzQMyHvtN87bi0Og',
#  'QbXGm8-MVfkjhHeh69SOaA',
#  'Y0ijlXfkpslSPRVkCzSivA',
#  'JqJnJhEldr9i3ns0hnw9iQ',
#  'LVNziG1I5DZpyp2lhg-14w',
#  'U4UTMWnXNWyeVFloMT6dLA',
#  'gmsVPTN-aGPl05fMgrRAfA',
#  'IGXk1jUh-jauSkqtBiXhhw',
#  '0HZEzKR6Z3Cze7EJI8U5TA',
#  '2inAYr-vK4v6pYQieOYt3g',
#  'gBGD0dNvfLlQOAaZzCU1NQ',
#  '2Ebrk8PbD5EZ9rZ_xUXPJQ',
#  'xhcgw9ye0eFSL_eAji0xbw',
#  'TRxR32_T_7Ly_RW4Ke97fw',
#  'DBpOYGNEwA4cC5xhJ6T87g',
#  'okwxHc4gTPXDdKjgu5B-PQ',
#  'mhoNEc-QXrGpNBHj_YfTzg',
#  'oEbpO3vmcrGDW2mtb_s8cQ',
#  '1HRAmY7rTMKaY9-rNrppzg',
#  'eQjN4s90I1fr-0DiLvEGTg',
#  'WyqkSiC5aUdZ0mvMGTPAKg',
#  'g9PNGCJL8kSDMygXT63m5w',
#  'gJUKVVUDHMtWolPcEB52hA',
#  'qeue741QLmfoDCbgSrZTLQ',
#  '61wOYrhTgEf-Xjif7lCREQ',
#  'yuNCCrY7IkaR58M5r2_zWQ',
#  '1hZDsxVg5SqDJg6PF00sTA',
#  '9ENaqsYVqKbsFL7zd2RKvQ',
#  'Jy1Cu7KvaVlYCyze8-3krQ',
#  'O-oZQR4N3RvHlLPgGdhryg',
#  '1ZLXSu-tw6dOQW6C4B6HPQ',
#  's5LXA40JYWTOZHmWJvXJUw',
#  'o3hDZ2nv80tApZMNQw2aZA',
#  'HpEdtyRSXSq0vCd556ucmw',
#  'Y5GT48Eysg_Ha33NIJPUJQ',
#  'AKqV-HnoWsgHgKtfVW_JJQ',
#  '4AXFhYxajBsUIusaGNrarA',
#  'xjv0mXQKjdM_0SHYk818kQ',
#  '1-9am0VPhPfoOqDVHhzWow',
#  'M27rUS5CRAmKcWZC6AMWDA',
#  'ftw-PVfHugd_Nj_xZPAWwg',
#  'X-t5_NmzJWDZk3J-sAheew',
#  'BIfja4aMJhMOs5hLO_V81A',
#  'v1dOT_0SGxKT51tN-jXTxw',
#  'UNeKk50r34xuylQ1t_ntoA',
#  'd4lxsAT2tpT-YDKD3MUMQQ',
#  '1W4gz758cCBQHEmlCAycPA',
#  '9vRUeYP5iTr0-uYMCD3TCg',
#  'fsrclV85MTmg3npCmpxOuw',
#  'wPViqOIThG5W_p4FKGqjrQ',
#  '_ypWevptFP02dSaf_IELxw',
#  'ZjXLrHtGEEF9uGuMw_3V1Q',
#  'bgiUnt6-CNh3OK9DCmWDPg',
#  '76ouVMYq0nLRyY_xeq2v7Q',
#  '4P6sn5nKJ2KFYrHUF4-qiA',
#  '-5SVdM5aY3rjGsQuiFAYjQ',
#  'H0LcjqWfgCFapQVTVmb0uw',
#  'clP29Ua9udDozyvAqmPVoQ',
#  'yAhLJXUzBJnwnLXeexTFhg',
#  'HNZhONELT14glwQXqaQuag',
#  'w2NiG6ftSvpU81eRghLIjQ',
#  'bbhIlhEqVdTZdUbSHeXtSw',
#  '-nJneX7sUX8gCZH1zsa4Qg',
#  'Ka2ZDJpkzCPe1Gv-bg-MDg',
#  'PScnKwDfJDPZbh-paDar7Q',
#  '4ah9n9KooJrScU3XuxMZeQ',
#  't_yrGGMDQOJ40U54F4gOEw',
#  'YoU4Do4kfQ_CK91bx83X8A',
#  'ftBGLu2SNf70z6KeOJ_FFQ',
#  'J8yQM9YWKWLyeadqUgU8zg',
#  'x2F34anSA7cH64owjdK13g',
#  'iahKDHG2CQ28WUP7kwfzmA',
#  'OpeMMntEiZdpptHhNsH84Q',
#  'pEigbPVK0uIX2rgvY7V1Xw',
#  'zVRKhZcZ63d6sI3TlEZvwQ',
#  'QrO4-F28JK4mQLP3eDbQ0A',
#  'kT8pqMXPDTpBHAhJR2mDqA',
#  'yDYj2essjns8V94DQpfVdw',
#  'xlzYL_Dwm7RdQzhC0FQgkw',
#  'a_yF7v2Odo-BdupM5rBlfQ',
#  '2LWQUpMuHVPG_McBtMLoLA',
#  'NbHslqct12sEXFpL41dTJA',
#  'g5mT_gT14l1AcbO4XGvAgA',
#  '9uqc6DXFBKGXnGIBTMSbqA',
#  'NgqIyv9Ld8i_rMPaEmGexw',
#  '_u8edvxkrqEWXoMYRh9AdA',
#  '_9ADdtDC_DZQ9CaUEnZ03Q',
#  'FsZXf_C0nYUn51R6JzqJxg',
#  'xdDXRgg9MOowJOCSKvrROQ',
#  '3xn6ED8KOhT6PU-EW5x-Iw',
#  'QyQJZT5BSup6aXUTHeNW3Q',
#  'Zh1cd9cjlCBFyrPbtC_4dA',
#  'WkhJGvtRAx6-zBn8klWNFw',
#  'LPTZ42e3u9JsJqyyf_J4rw',
#  'n_UrYjNafyzDCRcwiugnJA',
#  '1OZgJmh-cLfA2suDdvaQXQ',
#  'NG8HqWMJ_jXGRc2RirkfjQ',
#  'y9dZ9AUSluoLdw-h5-04Pg',
#  '-Mv885wiVkF5LByWUo-XjA',
#  '6J_a84ykDMSmn9-K_dJDyQ',
#  'U7qT9LGxkYkj9L_te5RqlA',
#  'ulFLsCym5q7H-ZuL93csSw',
#  'fi5t3_81nKx2Lbabi_w8ag',
#  'k7S7H5jHWkJrObxVn1eKYw',
#  '0VbQPOI8LqNpSmW4rcEMdQ',
#  'FQexbHk0m-AFVUUqjbeYYg',
#  'lyyIklgFipvDmimx6X_r2A',
#  'TCrlNxAdFhgYQRhNGtRGcw',
#  'gg-rXOYnRTRK073FZBtUYQ',
#  '5syhoAbcn673emva1wmQnQ',
#  'Yy7oNvAgFKRjl2u35HwepQ',
#  'wgIXVI9Ill28LXJmZvyukQ',
#  '2Ge49Uh3i9IrtQIIKPDGDA',
#  'JurrJfACafiCvx8J7NJK1w',
#  '0TgX65_sfyJ-0UfoRgWeuw',
#  'TGrkj9rFMckdPVtVWev11g',
#  '7Q6d5bfeAAALUwsPgowtig',
#  'KMNWw8GV_dlLu8VhfF0vVQ',
#  'KfWCXtyaE7CzQaEhq4_csQ',
#  'Cf2C_WP58vYd3GXqRDuIPA',
#  'cuWLMoy3aOyzUuDfi2XoIQ',
#  'cFk2SMsJ-2cmXKLFFkP9JA',
#  '-Cg7YHZruPxmj--xoefNvQ',
#  'qSAx7HfXDR-WOOjCqY7z4Q',
#  'g9L4Y9EgNzcj77zQkXK1rA',
#  'JR-3zeQUyOyoF96GgmrQoQ',
#  'zP5YbA32_VWt6buNzfRZTQ',
#  'huiEnwflRkpg4M5BKZcHdA',
#  'hR48gsFU8aHOjNbYm987jA',
#  'iuhZSdAQqDs4kYh7rHjXZg',
#  'ExnM1b-gxSODuDfVQ14TIQ',
#  'A1CJoUUAOeql0H0NtmtLgg',
#  '52lIpf9JbP9PnkQS0NAKZw',
#  'CFyOrr--MWtxgjZvaHHV6Q',
#  'skKyK9rTYnkPCO23dNWy8w',
#  'wVwgyzd8KruIK-HC2OHwsg',
#  'vQrXwWBs6Yrv46YFMIZRmQ',
#  'c8ZasXeA6P1s8JBzTj1XIw',
#  'aM3gFY8Eq2KJuvNBlGPJEA',
#  'm7tneh7Lagfhlb-ZotWTaA',
#  '8UPUaIMjeQEPibdmYrXPJA',
#  'IdIOZSbnLRcN1dG5PDXDeA',
#  'Zk1lvwSdMk8HeXMAPQBUqw',
#  '8qCi9Jiq6wPAszDWdOnK3Q',
#  'p8dyVyahA_yWajfJPnFFeA',
#  'BQBuDO0hF_nmiO1QFbh3kg',
#  'x7uujd_IgkV8W0wfI1-R3A',
#  '0Y8xQvpbmO02SsFZtamR5A',
#  'qWlAXLsnFZP0IOZXb3L8yQ',
#  'ej9pUnxdmb1YNCuyVu83Yw',
#  '1tMAIFA_OcXhEB5-gnh50A',
#  'KQYlIH2_HhP7_btwAAA4Hg',
#  '0DPQukWX45rqOIfDV40e3g',
#  '05ZNtpZKsBqtVAS-f3xg7Q',
#  'o0mknvICmptZ4pLxZkd9zQ',
#  'nNnpgZ00k6BTqP9W4OAwDg',
#  'jF7eaANzVu7UIueZa4x16Q',
#  '4uSvwXB9rSijObRzZ-vMBg',
#  'XAaXtqL1_HsI2t6FEIrA8Q',
#  'pWr3Ma_WY7iOxqMXKa2sgA',
#  'eEOjt4nvC-KEujFctVDHyg',
#  '_kvfdSVhVG4F0I3lNIbpaA',
#  'pG5hLBK49Oz2TLX2qY6UQw',
#  'IQmCg432MswZdmD59HCCDQ',
#  'e6SC96GLKXjI84Kn7Dw_0w',
#  'eNplYNNQP9TIWVzejwIHow',
#  'FPwqG1XmEGk63xg1xehIPA',
#  'i2UHT7yW8ZUuCAPmicaEpg',
#  'HKweD7jQQpZgc6NaoltH2Q',
#  '0FZ4jHSfxbm4CIMBkGWCcQ',
#  'gu1XBRHx0v4PvFKcEYX65Q',
#  't8VFV7ntCcmIIcNquAmlmw',
#  'kWUj7_pD5NZarzOxct3U9Q',
#  'ssPpumxk0l2NfxyGoLhSDQ',
#  'qu84rS2gClt1MeSb99CrKg',
#  'X3ZfUIEY1y1wyacm_0D4rg',
#  'Psf1p-qzz1nnNlN6RepawQ',
#  'P-eXuqXk-L-bEtBort6RCQ',
#  'LyTT2Ysg0OpN7Vzo_6zKNw',
#  'iiaCBiInCRyIXbapUuIPtw',
#  '37yDMpWI6HBO2iW8slv7_Q',
#  'gkNFqSreKexZxC0BTqS4uw',
#  'fnIGembspgIfO0-SgJiadw',
#  '7OKS-jsJ_Z6mEsYkZ86LFw',
#  'H-3udsXhsSDrfwHdQUv1Zw',
#  'SVB0vvNS60UD8WACeUPNAw',
#  'NrebjbqpbDEz_pVYJ3aKIA',
#  'QMKHzrAgGwhj1mJMVLg7uA',
#  'aUIxqFAagzUXQGofvzhtaw',
#  'k8cv3Hnu69lGuf0mo1MOTQ',
#  'Onrlk9JMe3KesJJa5VLDFA',
#  'DJBqJaszqdZyvBn79fQzlg',
#  'kQhmw4RexXf6rfjpiysjkA',
#  'JZ52Zp0FyfkZ9hokzDCvNw',
#  'rB6z5upjjIH1_hi60XOxRA',
#  '6r9FNW0-4aKqbPCX7UxTZg',
#  'CJe_LK2wz0YPOWoPlNjXXA',
#  '9XaV1JNv1zS-uZ5aiS5Aug',
#  '-KJuzqptSAbZtTRgcyFduQ',
#  'L3kNChslTDjT6HTsaa-6BQ',
#  'jrgdYF3SQtY9u_069N4XmA',
#  'S8Px83t0l52hcRwE1phE5w',
#  'ZGOuX60oNVHWjcnnCnXXMw',
#  'goYLt6IEBt8QObdSeOw_fQ',
#  'p8ops2vIbZ_sfInT5vhJ0w',
#  'EMti-iNn83SGp3z6LngDWQ',
#  'NiX_nc8pf8vClgqzjpmLTw',
#  '8OaLyhhW6Y3la-ccOGu12Q',
#  '6CZO9uCVqf9b8P_bwvDEAQ',
#  'b0bH3xEoYk9TNpCh67oPqg',
#  'AyP0gA-Wt76v_IcjZfwdhA',
#  'StvjNbR6eOWZQCFduX45Mg',
#  'k-WYL4xVweUDDi4ITfCUiA',
#  'qexmwX9rP881dwHwo4qGBw',
#  'Kybn4WMr6uJx7a70q08n2g',
#  'SuzwgDT71HxOccHXsBpJag',
#  'XPpzGDEpSstNeSW8iOOdfw',
#  'iKV83dI9jNc5h6L41aaUdw',
#  'GZeqk7xHeM5AqJgGTJNzTw',
#  'XDsRQfERk6gguET0QXkpqg',
#  'kqt8O-XxMkE6ga42IPa7sA',
#  'C2nCFtXdiXGdH1ySk36LQQ',
#  'RY6o7Q5xoJqbI1QRSKeDKA',
#  'D5sOiYCUzjYczz1fDMm8Ig',
#  'z1N6X6DJxuwvrcPV9miMSQ',
#  'RCKbAKRkm-kOPcx8hqJrtg',
#  'IViBs8QaaIjsKBADVJxzfQ',
#  'TFl-F7XFWen6phlQq3iyeQ',
#  'QCPhg4xl22h2IuCKGmkaNw',
#  'mNYiaagB7eaz5Ld0NkTdaQ',
#  'xY14qt32t0Gi-Rpj1aKiJg',
#  'UM6XgOtTX4DWWcGDTWtjEg',
#  'C925zLMJaPWOFqpJmXvuBg',
#  '57O_o7JpIeTvdG0xTNyaZw',
#  '6QJeFZ1ZoNfboGxS1cr5dw',
#  'ggtDtInujw9EsjCXkeIjbQ',
#  'GTXSk8QyD7N1Un-tzgPw4g',
#  'NDUcOSgI0rrI69ezy4PrpA',
#  'D65DSQBkUXJrcVJdW3NJXw',
#  'aTuAILKQK9135utH5Wmxxg',
#  '39t-p5woEOErAhGXS1qjyQ',
#  '_vRvoyDL4Q5gN7vkSZNNIQ',
#  'YqWVZVsuE5B4a-Tp8ESvug',
#  'm-I15bDwVUMq52HKF6tGig',
#  'OshZe8R4Zhcy-TsjK5vJdg',
#  'bGEi2BqDNGYFDtNzJhpABw',
#  'eq4BzsUMGlVwZ-4WoHR1jQ',
#  '-Xld662dL8WxrwP--bclIQ',
#  'mhK2uIu7F06ypYdQ5ndmzg',
#  'VY_czFj3BMGpQapZtyCrgg',
#  'TxCTQS_LQfgB_RMUoiyymA',
#  'w3qwX82l2oSJ53TuChblZA',
#  'JszJI2Ewenggj8zh1o3B-Q',
#  'Z0lI1P8ZIvl8IDR2FPrb1w',
#  'Qcpr1ec0EX33ei6CG833eg',
#  'DbjfbHWS5aOtT16qfwbGNw',
#  'JmOL5qRHdqVqTQ1dp2ZKSQ',
#  'tUKNCjEwGsXxkwDuqQ6q9g',
#  'dIqni3toenZFY-JVrvMiDA',
#  'uRd7FZswDJ17-G-xQACLmw',
#  'eiHDhGn2AwLZ5jtSX79iAQ',
#  'R_u4QTal0d5f-FHr7BUXcw',
#  '8dz-LJzw9FJ7II5PS2z8vA',
#  '0RjPyWFWbU9ASePhyfoWwQ',
#  'YIFOvtfJBPCLx5X9M-hHvw',
#  'XghNsH2paJx4IWJ30YtowA',
#  'DtKuWE7Cpp0x3MphvrXUcg',
#  'g3DHFGXM1DPHd_e2xs3ANw',
#  'iJDhEQLDdqaCENyU7BGBFA',
#  '7I83yaco0OfOeBS9PSShvQ',
#  'GiDdx2KSSV2f-P6S6t_BZA',
#  'oj3yPa--Xz9jK9wTLq798A',
#  'Q40ZyZlTGeMU0FxOykvugg',
#  'fshdUiudX3YrEUSwZmN3jA',
#  'w-HSMd1RWm3fCu4LNOSA4A',
#  '47ls8ov8TpyuXcr4vhqlRw',
#  '5JhAZeEVc9L3Wtt__at0lQ',
#  'IkojivrPEM79yzhF3AzN1g',
#  'xfSI7F7QjHqWLvUnF7Gp5Q',
#  'eFXXx43yxvDJ0E9Jg-QP2g',
#  'UrsozEtJq1bS2Lu_dvOc3g',
#  'ySia3cfl7f8OscimUlTbjw',
#  'M-jVF2A2wXYMm8312MYP6A',
#  'g7yJzu-Uue85Up8J-52oJg',
#  '_Xck5LIn0CnWGRLfKv1J6g',
#  '2EWsaJdeedx_-my5fYEg9A',
#  '1Ly-Njk6U0kEq3TFnCgeWw',
#  '9hcNSNCnQkIVy5EsvY4NrA',
#  'Hb4r8q0_aRFjmvmxJc96uQ',
#  'am5qD6LFjkV8f_4MLp8Img',
#  'ncDxCFOZOl2OckF0lBY0Tw',
#  'WAKTg8KqVjy_LATtJ8l4Xw',
#  'iKxULnOA8_CO0OwmpZ_MyQ',
#  'DAn7drLq36AJlH9wagcA_Q',
#  'NNab8Ympt7XaVWGWjqoykg',
#  'xp0YgA_UP1GvTu4aVfwsSQ',
#  'EpcQdrEEAZtSErntI8n9VQ',
#  'PMy0RHS1kBn21rawoOWfow',
#  'ieJoATmf7T5b0NP6aFpC0Q',
#  '7rtbIYXGSFdZeKbIaif1vQ',
#  'OA6KVNzqFoQht06FkDkk5A',
#  'gPeYISq8pk8qDi3KdB83Gw',
#  '1XsoLhxLB7-iyxaLpoEmUg',
#  'oiZdfSO-b0MYmFgJNyLJ5g',
#  'CJfwiA0sBqRkhYakgXd65Q',
#  'Ye92i-yHEqCAgkNFShjm4w',
#  'u_KFt_3_M7pQZs5CFAKosQ',
#  'wqXxljKfGErIHz3LQfuQlg',
#  'ZpBGEwlHXPwChQNFzQlLgg',
#  'LLpsnCJFEyj55aA8ANLmog',
#  'v9cbyEnYeJ_QBj_3JdLatw',
#  'UxrzmxM9oYq4W2xbNttq1Q',
#  'Et3rSYz4NnXc0m6Kjg90zg',
#  'aFtKNDO9UVFi_0sFlw6Qcw',
#  'ZO5_G2k7DECPz2z2pMR_yA',
#  'z-_Gy3YNzYnr0Nb6BUyx7A',
#  'rnUMMRmaFQSec2D_N8yX0w',
#  'q5nmlxpyLN95f8ZnBThUWA',
#  'J6DWsBkHXwy6T3hnElUCJw',
#  'aBQJ0IJOqvFk9NF5LAekGA',
#  'SOb6JLw76tJ_NgG1l0XGdg',
#  'ojHdnmPu9omkPKK-fir7Vg',
#  'HmFzVCUOeo2lTJ0-vYtIOg',
#  'nEzPw-8PA3XyZZA7DZw3mQ',
#  'jci-jrsso9Ucn7r_kMsYAA',
#  'eURlTO9sTSDZtilnhgvxQA',
#  '8GW3J233ePBX7BlJcOAFUQ',
#  'NLtvrI7CKyMyo7emp7_z6g',
#  'jpm4b_k-dnByV39-NDsZBw',
#  'IgwciP_ypBDdg7Vh_IkW6A',
#  'BWh8oUADBbFTefhBZg5trw',
#  'G6N5IuqIwCbLeTjWkf1Dzw',
#  'di2mjpEsYputc9wRcQiEuw',
#  'D4spXIMXev6pFUz3df31fQ',
#  'othFMp54IBPLXLMsDYgu0g',
#  'kldxUk_h0wx7534Xl9K0bA',
#  '9QVTE7N-nET_tu7ky-Pibw',
#  'RzmzZEQO0ULe4l5tHvMMbg',
#  'fKvPZFJtkPGsWmJR4XSGzg',
#  'rZHN-ZzaEY7pAKrxpSS2yw',
#  'yIenLSHDB3yX3mIPU2l1hA',
#  '8vfPRZO9bjchz91Hh6_qRw',
#  'fh4pd6eQLQtKqPE_70oymw',
#  'qvGLXBFz8aiQqIrFWSX64w',
#  'SsLpA8PaS7CUidE5o6VoEg',
#  '61yOHKjRUdpDgYFHetE5QQ',
#  'zVvdqWz7_qjJf3X87Yqp2A',
#  'VN1QX6AAAqvmrEZVJTy-Qg',
#  'DXgJJgak1XmJRa1VPIPw7Q',
#  'vTBKqG5hmIta0NqtpbGg6Q',
#  'oKplSGIyrXvPXvSBfDzXiQ',
#  'c39Y2K2DIch1L2lAgi25QQ',
#  '5LAbWMJ6cEUgNtxklmYGqA',
#  '1NKWzcyga2c4agoykg2vdw',
#  'm30UqcBmRbBbVeerjg9q1A',
#  'pifFMhPvoh2ul4D93uX3cA',
#  'K80_VruUekDn_rNFLJpDCQ',
#  ...}

# %%
chunk_size = 10000

mo_business_reviews = []

for chunk in pd.read_json("../data/raw/review.json", lines=True, chunksize=chunk_size):
    filtered_chunk = chunk[chunk['business_id'].isin(mo_business_ids)]
    chunk_json = filtered_chunk.to_dict(orient="records")
    mo_business_reviews.extend(chunk_json)

# %%
len(mo_business_reviews)
# Out:
# 502385

# %%
mo_business_reviews[4]
# Out:
# {'review_id': '-up4mW6WdqzGrRh7t_pLmA',
#  'user_id': 'xbybLiQockAzC4xAlzFrGg',
#  'business_id': 'EpREWeEpmR8f1qLHzzF0AA',
#  'stars': 5,
#  'useful': 0,
#  'funny': 0,
#  'cool': 0,
#  'text': "After living in the STL area for way over 10 years now, I am both ashamed and remorseful to admit that I ate here for the FIRST time just a few weeks ago. I am ashamed because it's a St. Louis tradition and remorseful because I missed out on it for so..many...years! \n\nThis place is amazing. What is not to love! It's a factory where you can get a tour (Friday-Sunday, noon-5pm on the hour), there's a shop, bar, and dining area. They also host many event with live music on the weekends. It's fun to just kind of wander and look around - don't worry, you'll get a chance because there will likely be a wait before you dine. The beer is, of course, amazing. The Hefeweizen is my personal favorite and a great start for anyone who is not a huge beer drinker (like myself). Additionally, the food is homegrown and damn good. I had the pizza (recommendation from my server) and it was really spectacular, though I'm admittedly a pizza connoisseur so I enjoy a good pizza pie more than most probably ;P My date had a bison burger which was also really good. \n\nMore fun info: the service is great! I think they tend to hire more funky and alternative people (like tattoo parlor staff) which I support. The quality is what makes this place stand out along with the emphasis on local food and brewery. \n\nIt is a little on the pricier side but for all the experience you get and the quality, it is worth it. I will go again and again and you probably should, too!",
#  'date': Timestamp('2011-11-30 06:58:36')}

# %%
business_review_freq = defaultdict(int)

for review in mo_business_reviews:
    if review["business_id"]:
        business_review_freq[review["business_id"]] += 1

print(sorted(business_review_freq.items(), key=lambda l:-l[1])[:5])
# Out:
# [('I_3LMZ_1m2mzR0oLIOePIg', 4093), ('iRIHK8-EwpeffwvoO4nzIA', 2170), ('2BMk_drsikKWslJCXmQtjQ', 2023), ('R8t9g5nvi7VFyS8zsgmj8Q', 1788), ('cQIh4YJlVtZI9TLF5_smOg', 1781)]

# %%
mo_business[0]
# Out:
# {'business_id': 'mpf3x-BjTdTEA3yCZrAYPw',
#  'name': 'The UPS Store',
#  'address': '87 Grasso Plaza Shopping Center',
#  'city': 'Affton',
#  'state': 'MO',
#  'postal_code': '63123',
#  'latitude': 38.551126,
#  'longitude': -90.335695,
#  'stars': 3.0,
#  'review_count': 15,
#  'is_open': 1,
#  'attributes': {'BusinessAcceptsCreditCards': 'True'},
#  'categories': 'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services',
#  'hours': {'Monday': '0:0-0:0',
#   'Tuesday': '8:0-18:30',
#   'Wednesday': '8:0-18:30',
#   'Thursday': '8:0-18:30',
#   'Friday': '8:0-18:30',
#   'Saturday': '8:0-14:0'}}

# %%
mo_business_reviews[0]
# Out:
# {'review_id': 'XW_LfMv0fV21l9c6xQd_lw',
#  'user_id': '9OAtfnWag-ajVxRbUTGIyg',
#  'business_id': 'lj-E32x9_FA7GmUrBGBEWg',
#  'stars': 4,
#  'useful': 0,
#  'funny': 0,
#  'cool': 0,
#  'text': "Love going here for happy hour or dinner!  Great patio with fans to beat the StL heat!   Also...very accomodating at this location.  I like the Veal Milanese but with mixed greens instead of pasta!  they'll modify the menu to suit your taste!",
#  'date': Timestamp('2014-06-27 22:44:01')}

# %%
mo_business_reviews_df = pd.DataFrame(mo_business_reviews)

# %%
mo_business_reviews_df['date'] = mo_business_reviews_df['date'].astype(str)

# %%
mo_business_reviews_df.to_csv('mo_business_reviews.csv',index=False)

# %%
mo_business_reviews_df.to_json('mo_business_reviews.json', orient="records", indent=4)

# %% [markdown]
# # New Statistics

# %% [markdown]
# # Writing Style
